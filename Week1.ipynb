# %% [markdown]
# # Automated Intern Hiring Algorithm
# This dataset `hiring.csv` is about summer internship applications at a large tech company. Each row of the dataset is an individual student applicant. This data could be used to build a machine learning model to predict which applicants are most likely to be hired. This model could be used to automate all or part of the hiring process.
#
# **Your goal in this assignment is to understand the data and how biases can emerge in datasets.**
#
#
# ## Part 1: Data Exploration (5 pts)
#
# Upload the .zip file (`hw1data.zip`) included in the homework assignment. I **strongly** recommend using the following code rather than the Colab web interface for uploading files, particularly for those with slower internet connections.

# %%
from google.colab import files
uploaded = files.upload()

# %%
import zipfile
import io
zf = zipfile.ZipFile(io.BytesIO(uploaded['hw1data.zip']),"r")
zf.extractall()

# %% [markdown]
# The first few exercises will get you used to looking at the data using `pandas`. Pandas is a widely used library in python for manipulating data.
#
# > *Optional: Why? Datasets can consume a _lot_ of space in your computer's memory and traditional python data structures like lists or dictionaries will become painfully slow as we add thousands of rows of data. We use a specialized dataset library `pandas` which has a specialized data structure called a `dataframe` designed to be ultra fast & efficient. Documentation is here: https://pandas.pydata.org/pandas-docs/stable/*

# %%
import pandas as pd # import pandas library
df = pd.read_csv('hw1data/hiring.csv', low_memory=False) # read the csv file into a pandas dataframe object

# %% [markdown]
# To understand what kind of data was collected, `pandas` has some handy commands:
# - `df.head()` will show us the first 5 rows of our dataset. You can also specify the first N rows, like `df.head(18)` will show us the first 18 rows.
# - `df.sample(10)` will show us 10 randomly sampled rows of our dataset
# - `df.shape` will tell us how many rows and how many columns are in the dataset
# - `df.columns` will list the names of all columns in the dataset
# - `df.describe()` will give you summary statistics about all numerical columns in the dataset
#
#
#
# ### Question 1.A:  How many rows are in this dataset? How many columns? (1 pt)
# _Double click to write your answer question here. Show your work in code below if applicable._

# %% [markdown]
# ### Question 1.B: One of the columns in the dataset is the outcome value for each application, the value we will try to predict. What is the name of that column? (1 pt)
# _Double click to write your answer question here. Show your work in code below if applicable._

# %% [markdown]
# ### Question 1.C: Given the columns in this dataset, think about what information you _don't_ have about each application. Rank your top 3 _missing_ pieces of information about each application that could be important for deciding which applicants to hire. (3 pts)
# _Double click to write your answer question here. Justify your answer._
# #1.
# #2.
# #3.

# %% [markdown]
# ## Part 2: Understanding Bias in Datasets (5 pts)
#
# ### Question 2.A: Does the likelihood of being hired differ by college type in this data? (2 pts)
#
# You may find the [groupby](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.groupby.html) function useful for answering this question.
#
# _Double click to write your answer question here. Show your work in code below if applicable._

# %% [markdown]
# ### Question 2.B: Would you expect a model trained on this data to exhibit bias with respect to gender, race, and/or age? Why or why not? (3 pts)
#
# _Double click to write your answer question here. Show your work in code below if applicable._

# %% [markdown]
# ## Part 3: Helping Others Understand Fairness & Bias (10 pts)
#
# Imagine that you work as a software engineer for this tech company. Your boss has asked you to build a machine learning system to help automate the hiring process for summer interns.
#
# There are two possible data sets you could you use (included in the assignment materials in data.zip: hiring.csv and awards.csv). The first dataset identifies which applicants were given internship offers for the summer 2022 and which applicants were rejected. The second dataset identifies which interns from the past five summers received awards for excellent performance during their internship. You need to design a visualization that will convince your boss to use the data set that you think is the right choice.
#
# ### Part 3.A: List the three most important attributes of the datasets that you think should be considered to decide which dataset to use. Justify your answers. (3 pts)

# %% [markdown]
# _Double click to write your answer to the question here._
# #1.
# #2.
# #3.

# %% [markdown]
# ### Part 3.B: Sketch a visualization that your boss (who is not a software engineer) can understand, that will help your boss understand the dataset and the aspects of it that you consider important. Include a brief written description of how your visualization acheives this goal. (5 pts)
#
# Below we include two examples of visualizations that would receive full points. Your visualization should:
#
# 1.   be distinct from the examples below (2 pts)
# 2.   highlight aspects of the dataset(s) that you consider important (2 pts)
# 3.   be annotated with a brief written description of how it will help your boss understand the aspects of the datasets that you consider important (1 pt)

# %% [markdown]
# ![Screen Shot 2022-09-21 at 7.45.54 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![hw1sketch.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# _Attach a **pdf** with your sketches. Please include any annotations/description on the pdf itself (not in this notebook)._

# %% [markdown]
# ### Part 3.C: Do you think that automating the hiring process this way is a good idea? Why or why not? (2 pts)

# %% [markdown]
# _Double click to write your answer to the question here._
